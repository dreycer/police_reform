# %% [markdown]
# # Voting Data Cleaning
#
# * [Imports](#Imports)
# * [Cleaning](#Cleaning)
#
# ## Imports

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../data/countypres_2000-2020.csv')
df.head()
# Out:
#    year    state state_po county_name  county_fips     office       candidate  \
# 0  2000  ALABAMA       AL     AUTAUGA       1001.0  PRESIDENT         AL GORE
# 1  2000  ALABAMA       AL     AUTAUGA       1001.0  PRESIDENT  GEORGE W. BUSH
# 2  2000  ALABAMA       AL     AUTAUGA       1001.0  PRESIDENT     RALPH NADER
# 3  2000  ALABAMA       AL     AUTAUGA       1001.0  PRESIDENT           OTHER
# 4  2000  ALABAMA       AL     BALDWIN       1003.0  PRESIDENT         AL GORE
#
#         party  candidatevotes  totalvotes   version   mode
# 0    DEMOCRAT          4942.0     17208.0  20191203  TOTAL
# 1  REPUBLICAN         11993.0     17208.0  20191203  TOTAL
# 2       GREEN           160.0     17208.0  20191203  TOTAL
# 3       OTHER           113.0     17208.0  20191203  TOTAL
# 4    DEMOCRAT         13997.0     56480.0  20191203  TOTAL

# %%
df.shape
# Out:
# (72617, 12)

# %%
df = df[df['year'] == 2020]

# %%
df.shape
# Out:
# (22093, 12)

# %%
df.head(10)
# Out:
#        year    state state_po county_name  county_fips     office  \
# 50524  2020  ALABAMA       AL     AUTAUGA       1001.0  PRESIDENT
# 50525  2020  ALABAMA       AL     AUTAUGA       1001.0  PRESIDENT
# 50526  2020  ALABAMA       AL     AUTAUGA       1001.0  PRESIDENT
# 50527  2020  ALABAMA       AL     BALDWIN       1003.0  PRESIDENT
# 50528  2020  ALABAMA       AL     BALDWIN       1003.0  PRESIDENT
# 50529  2020  ALABAMA       AL     BALDWIN       1003.0  PRESIDENT
# 50530  2020  ALABAMA       AL     BARBOUR       1005.0  PRESIDENT
# 50531  2020  ALABAMA       AL     BARBOUR       1005.0  PRESIDENT
# 50532  2020  ALABAMA       AL     BARBOUR       1005.0  PRESIDENT
# 50533  2020  ALABAMA       AL        BIBB       1007.0  PRESIDENT
#
#                candidate       party  candidatevotes  totalvotes   version  \
# 50524  JOSEPH R BIDEN JR    DEMOCRAT          7503.0     27770.0  20210622
# 50525              OTHER       OTHER           429.0     27770.0  20210622
# 50526     DONALD J TRUMP  REPUBLICAN         19838.0     27770.0  20210622
# 50527  JOSEPH R BIDEN JR    DEMOCRAT         24578.0    109679.0  20210622
# 50528              OTHER       OTHER          1557.0    109679.0  20210622
# 50529     DONALD J TRUMP  REPUBLICAN         83544.0    109679.0  20210622
# 50530  JOSEPH R BIDEN JR    DEMOCRAT          4816.0     10518.0  20210622
# 50531              OTHER       OTHER            80.0     10518.0  20210622
# 50532     DONALD J TRUMP  REPUBLICAN          5622.0     10518.0  20210622
# 50533  JOSEPH R BIDEN JR    DEMOCRAT          1986.0      9595.0  20210622
#
#         mode
# 50524  TOTAL
# 50525  TOTAL
# 50526  TOTAL
# 50527  TOTAL
# 50528  TOTAL
# 50529  TOTAL
# 50530  TOTAL
# 50531  TOTAL
# 50532  TOTAL
# 50533  TOTAL

# %% [markdown]
# ## Cleaning

# %%
df.isnull().sum()
# Out:
# year              0
# state             0
# state_po          0
# county_name       0
# county_fips       9
# office            0
# candidate         0
# party             0
# candidatevotes    1
# totalvotes        5
# version           0
# mode              0
# dtype: int64

# %% [markdown]
# Making sure I'm only looking at presidential campaign results from 2020.

# %%
df['office'].unique()
# Out:
# array(['PRESIDENT', 'US PRESIDENT'], dtype=object)

# %% [markdown]
# Checking which county fips are null.

# %%
df[df['county_fips'].isnull()]
# Out:
#        year                 state state_po           county_name  county_fips  \
# 53317  2020  DISTRICT OF COLUMBIA       DC  DISTRICT OF COLUMBIA          NaN
# 53318  2020  DISTRICT OF COLUMBIA       DC  DISTRICT OF COLUMBIA          NaN
# 53319  2020  DISTRICT OF COLUMBIA       DC  DISTRICT OF COLUMBIA          NaN
# 53320  2020  DISTRICT OF COLUMBIA       DC  DISTRICT OF COLUMBIA          NaN
# 53321  2020  DISTRICT OF COLUMBIA       DC  DISTRICT OF COLUMBIA          NaN
# 63983  2020          RHODE ISLAND       RI      FEDERAL PRECINCT          NaN
# 63984  2020          RHODE ISLAND       RI      FEDERAL PRECINCT          NaN
# 63985  2020          RHODE ISLAND       RI      FEDERAL PRECINCT          NaN
# 63986  2020          RHODE ISLAND       RI      FEDERAL PRECINCT          NaN
#
#           office          candidate        party  candidatevotes  totalvotes  \
# 53317  PRESIDENT  JOSEPH R BIDEN JR     DEMOCRAT        317323.0    344356.0
# 53318  PRESIDENT              OTHER        GREEN          1726.0    344356.0
# 53319  PRESIDENT       JO JORGENSEN  LIBERTARIAN          2036.0    344356.0
# 53320  PRESIDENT              OTHER        OTHER          4685.0    344356.0
# 53321  PRESIDENT     DONALD J TRUMP   REPUBLICAN         18586.0    344356.0
# 63983  PRESIDENT  JOSEPH R BIDEN JR     DEMOCRAT          1276.0      1374.0
# 63984  PRESIDENT       JO JORGENSEN  LIBERTARIAN             6.0      1374.0
# 63985  PRESIDENT              OTHER        OTHER             7.0      1374.0
# 63986  PRESIDENT     DONALD J TRUMP   REPUBLICAN            85.0      1374.0
#
#         version   mode
# 53317  20210622  TOTAL
# 53318  20210622  TOTAL
# 53319  20210622  TOTAL
# 53320  20210622  TOTAL
# 53321  20210622  TOTAL
# 63983  20210622  TOTAL
# 63984  20210622  TOTAL
# 63985  20210622  TOTAL
# 63986  20210622  TOTAL

# %% [markdown]
# Explored this - was unable to find information about why this would be not listed for county. From everything I found, Rhode Island only had the 5 counties, all of which were already represented in the dataframe. I chose to delete the rows that listed Federal Precinct as the county.

# %%
df[df['county_name'] == 'FEDERAL PRECINCT']
# Out:
#        year         state state_po       county_name  county_fips     office  \
# 63983  2020  RHODE ISLAND       RI  FEDERAL PRECINCT          NaN  PRESIDENT
# 63984  2020  RHODE ISLAND       RI  FEDERAL PRECINCT          NaN  PRESIDENT
# 63985  2020  RHODE ISLAND       RI  FEDERAL PRECINCT          NaN  PRESIDENT
# 63986  2020  RHODE ISLAND       RI  FEDERAL PRECINCT          NaN  PRESIDENT
#
#                candidate        party  candidatevotes  totalvotes   version  \
# 63983  JOSEPH R BIDEN JR     DEMOCRAT          1276.0      1374.0  20210622
# 63984       JO JORGENSEN  LIBERTARIAN             6.0      1374.0  20210622
# 63985              OTHER        OTHER             7.0      1374.0  20210622
# 63986     DONALD J TRUMP   REPUBLICAN            85.0      1374.0  20210622
#
#         mode
# 63983  TOTAL
# 63984  TOTAL
# 63985  TOTAL
# 63986  TOTAL

# %%
df = df[~df.county_name.str.contains("FEDERAL PRECINCT")]

# %% [markdown]
# The only other location missing FIPS was DC. I looked up the FIPS code and imputed. [Source](https://dc.postcodebase.com/county/11001)

# %%
df[df['county_fips'].isnull()]
# Out:
#        year                 state state_po           county_name  county_fips  \
# 53317  2020  DISTRICT OF COLUMBIA       DC  DISTRICT OF COLUMBIA          NaN
# 53318  2020  DISTRICT OF COLUMBIA       DC  DISTRICT OF COLUMBIA          NaN
# 53319  2020  DISTRICT OF COLUMBIA       DC  DISTRICT OF COLUMBIA          NaN
# 53320  2020  DISTRICT OF COLUMBIA       DC  DISTRICT OF COLUMBIA          NaN
# 53321  2020  DISTRICT OF COLUMBIA       DC  DISTRICT OF COLUMBIA          NaN
#
#           office          candidate        party  candidatevotes  totalvotes  \
# 53317  PRESIDENT  JOSEPH R BIDEN JR     DEMOCRAT        317323.0    344356.0
# 53318  PRESIDENT              OTHER        GREEN          1726.0    344356.0
# 53319  PRESIDENT       JO JORGENSEN  LIBERTARIAN          2036.0    344356.0
# 53320  PRESIDENT              OTHER        OTHER          4685.0    344356.0
# 53321  PRESIDENT     DONALD J TRUMP   REPUBLICAN         18586.0    344356.0
#
#         version   mode
# 53317  20210622  TOTAL
# 53318  20210622  TOTAL
# 53319  20210622  TOTAL
# 53320  20210622  TOTAL
# 53321  20210622  TOTAL

# %%
df['county_fips'].fillna(11001, inplace=True)

# %% [markdown]
# Discovered that San Joaquin county in CA had null values for OTHER candidate votes and for all of their total votes. I researched and imputed values. [Source](https://www.sjgov.org/WorkArea/DownloadAsset.aspx?id=33619)

# %%
df[df['candidatevotes'].isnull()]
# Out:
#        year       state state_po  county_name  county_fips     office  \
# 52848  2020  CALIFORNIA       CA  SAN JOAQUIN       6077.0  PRESIDENT
#
#       candidate  party  candidatevotes  totalvotes   version   mode
# 52848     OTHER  OTHER             NaN         NaN  20210622  TOTAL

# %%
df.loc[52848, 'candidatevotes'] = 4617

# %%
null_totalvotes = list(df[df['totalvotes'].isnull()].index)
total_votes = df[df['county_name'] == 'SAN JOAQUIN'].candidatevotes.sum()

for index in null_totalvotes: 
    df.loc[index, 'totalvotes'] = total_votes

# %% [markdown]
# Like my other data sets, I needed to add the beginning zeros to some of the FIPS codes to make certain they were all 5 digits. This will help when I merge this data with my Demographics Dataframe.

# %%
df['county_fips'] = [int(val) for val in df.county_fips]

# %%
# function to concatenate two numbers
# source: https://stackoverflow.com/questions/12838549/how-to-concatenate-two-integers-in-python
def concat(a, b):
    return (f"{a}{b}")

county_5_digits = []
for code in df['county_fips']:
    if (len(str(code))) == 5:
        county_5_digits.append(str(code))
    else:
        county_5_digits.append(concat('0', code))

df['county_fips'] = county_5_digits

# %% [markdown]
# I want to create a new dataframe with each row as a county and three columns: percent that voted Republican, percent that voted Democrat, percent voted Other. I am curious about whether it would improve my clustering model.

# %%
# change 'state' and county to title case
# will help with merging
df['state'] = [state.title() for state in df['state']]
df['county_name'] = [county.title() for county in df['county_name']]

# %%
df['candidate'].value_counts()
# Out:
# OTHER                6903
# DONALD J TRUMP       5116
# JOSEPH R BIDEN JR    5116
# JO JORGENSEN         4954
# Name: candidate, dtype: int64

# %% [markdown]
# I will lump Jo Jorgensen with 'other' to simplify and only have 3 additional columns to add to my demographics dataframe.

# %%
df['candidate'] = np.where(df['candidate'] == 'JO JORGENSEN', 'OTHER', df['candidate'])

# %%
df.candidate.value_counts()
# Out:
# OTHER                11857
# DONALD J TRUMP        5116
# JOSEPH R BIDEN JR     5116
# Name: candidate, dtype: int64

# %% [markdown]
# I created three new columns, each representing the percentage of the vote that the democrats got, one for republicans, and one for other.

# %%
df['dem_percent'] = np.where(df['candidate'] == 'JOSEPH R BIDEN JR', df['candidatevotes']/df['totalvotes'], 0)
df['rep_percent'] = np.where(df['candidate'] == 'DONALD J TRUMP', df['candidatevotes']/df['totalvotes'], 0)
df['other_percent'] = np.where(df['candidate'] == 'OTHER', df['candidatevotes']/df['totalvotes'], 0)

# %%
df.head()
# Out:
#        year    state state_po county_name county_fips     office  \
# 50524  2020  Alabama       AL     Autauga       01001  PRESIDENT
# 50525  2020  Alabama       AL     Autauga       01001  PRESIDENT
# 50526  2020  Alabama       AL     Autauga       01001  PRESIDENT
# 50527  2020  Alabama       AL     Baldwin       01003  PRESIDENT
# 50528  2020  Alabama       AL     Baldwin       01003  PRESIDENT
#
#                candidate       party  candidatevotes  totalvotes   version  \
# 50524  JOSEPH R BIDEN JR    DEMOCRAT          7503.0     27770.0  20210622
# 50525              OTHER       OTHER           429.0     27770.0  20210622
# 50526     DONALD J TRUMP  REPUBLICAN         19838.0     27770.0  20210622
# 50527  JOSEPH R BIDEN JR    DEMOCRAT         24578.0    109679.0  20210622
# 50528              OTHER       OTHER          1557.0    109679.0  20210622
#
#         mode  dem_percent  rep_percent  other_percent
# 50524  TOTAL     0.270184     0.000000       0.000000
# 50525  TOTAL     0.000000     0.000000       0.015448
# 50526  TOTAL     0.000000     0.714368       0.000000
# 50527  TOTAL     0.224090     0.000000       0.000000
# 50528  TOTAL     0.000000     0.000000       0.014196

# %%
df_by_county = df.groupby(['state', 'county_name']).sum().reset_index()

# %%
df_by_county.drop(columns=['year', 'candidatevotes', 'version'], inplace=True)

# %%
df_by_county.head()
# Out:
#      state county_name  totalvotes  dem_percent  rep_percent  other_percent
# 0  Alabama     Autauga     83310.0     0.270184     0.714368       0.015448
# 1  Alabama     Baldwin    329037.0     0.224090     0.761714       0.014196
# 2  Alabama     Barbour     31554.0     0.457882     0.534512       0.007606
# 3  Alabama        Bibb     28785.0     0.206983     0.784263       0.008755
# 4  Alabama      Blount     82764.0     0.095694     0.895716       0.008591

# %% [markdown]
# Exporting as csv

# %%
df_by_county.to_csv('../data/voting_by_county_clean.csv')
